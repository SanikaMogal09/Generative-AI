# %%
! pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (1.2.13)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (2.13.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (0.6.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain_community) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.1)
# Requirement already satisfied: anyio in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install langchain chromadb  tiktoken pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (1.2.10)
# Requirement already satisfied: chromadb in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (1.5.5)
# Requirement already satisfied: tiktoken in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (0.12.0)
# Requirement already satisfied: pypdf in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (6.9.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain) (1.2.13)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (2.13.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: packaging>=24.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: certifi in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.6.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: flatbuffers in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: filelock in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: colorama in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U langchain-huggingface
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (1.2.0)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-1.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-huggingface) (1.2.13)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: requests in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sanika mogal\onedrive\desktop\gen ai by campusx\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.16.0)
# Downloading langchain_huggingface-1.2.1-py3-none-any.whl (30 kB)
# Installing collected packages: langchain-huggingface
#   Attempting uninstall: langchain-huggingface
#     Found existing installation: langchain-huggingface 1.2.0
#     Uninstalling langchain-huggingface-1.2.0:
#       Successfully uninstalled langchain-huggingface-1.2.0
# Successfully installed langchain-huggingface-1.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)

# %%
from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document 

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['b7c7e95d-1284-446b-bb23-8c942798e5bc',
#  '1a213375-63f3-4391-84de-bdfe2e60219c',
#  'fa38394a-3aa0-4033-9cad-c1769812868f',
#  'befb6d7c-fbcc-438e-8fc6-62880aa387e6',
#  '4b66a336-5757-48f8-a0fb-551a254b2e3d']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['b7c7e95d-1284-446b-bb23-8c942798e5bc',
#   '1a213375-63f3-4391-84de-bdfe2e60219c',
#   'fa38394a-3aa0-4033-9cad-c1769812868f',
#   'befb6d7c-fbcc-438e-8fc6-62880aa387e6',
#   '4b66a336-5757-48f8-a0fb-551a254b2e3d'],
#  'embeddings': array([[ 0.00994729,  0.06914339, -0.05147116, ..., -0.03543336,
#           0.01284811,  0.0124829 ],
#         [ 0.00127744,  0.03129851, -0.02375377, ..., -0.00518359,
#          -0.03280612,  0.02737716],
#         [-0.10265917,  0.02650811,  0.022715  , ..., -0.03359742,
#          -0.07984947, -0.0150771 ],
#         [ 0.02123394, -0.02468546, -0.04494373, ..., -0.10995814,
#           0.0057256 ,  0.09915376],
#         [ 0.0187398 ,  0.04382848, -0.04304255, ..., -0.07801621,
#          -0.0784068 , -0.00304188]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=1
)
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693601727485657),
#  (Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.14934504032135)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436005115509033),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.890937328338623)]

# %%
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='b7c7e95d-1284-446b-bb23-8c942798e5bc', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['b7c7e95d-1284-446b-bb23-8c942798e5bc',
#   '1a213375-63f3-4391-84de-bdfe2e60219c',
#   'fa38394a-3aa0-4033-9cad-c1769812868f',
#   'befb6d7c-fbcc-438e-8fc6-62880aa387e6',
#   '4b66a336-5757-48f8-a0fb-551a254b2e3d'],
#  'embeddings': array([[-0.00233745,  0.05902083, -0.04774046, ..., -0.0726405 ,
#           0.00276781, -0.00344084],
#         [ 0.00127744,  0.03129851, -0.02375377, ..., -0.00518359,
#          -0.03280612,  0.02737716],
#         [-0.10265917,  0.02650811,  0.022715  , ..., -0.03359742,
#          -0.07984947, -0.0150771 ],
#         [ 0.02123394, -0.02468546, -0.04494373, ..., -0.10995814,
#           0.0057256 ,  0.09915376],
#         [ 0.0187398 ,  0.04382848, -0.04304255, ..., -0.07801621,
#          -0.0784068 , -0.00304188]], shape=(5, 384)),
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['b7c7e95d-1284-446b-bb23-8c942798e5bc'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['1a213375-63f3-4391-84de-bdfe2e60219c',
#   'fa38394a-3aa0-4033-9cad-c1769812868f',
#   'befb6d7c-fbcc-438e-8fc6-62880aa387e6',
#   '4b66a336-5757-48f8-a0fb-551a254b2e3d'],
#  'embeddings': array([[ 0.00127744,  0.03129851, -0.02375377, ..., -0.00518359,
#          -0.03280612,  0.02737716],
#         [-0.10265917,  0.02650811,  0.022715  , ..., -0.03359742,
#          -0.07984947, -0.0150771 ],
#         [ 0.02123394, -0.02468546, -0.04494373, ..., -0.10995814,
#           0.0057256 ,  0.09915376],
#         [ 0.0187398 ,  0.04382848, -0.04304255, ..., -0.07801621,
#          -0.0784068 , -0.00304188]], shape=(4, 384)),
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
